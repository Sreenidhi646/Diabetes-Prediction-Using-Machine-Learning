# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\hemae\OneDrive\Desktop\diabetes\diabetes_prediction_dataset.csv')

# %% [markdown]
# # 1) Explore Data

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# # 2) Find Null Values

# %%
(df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
# Out:
# gender                 0.0
# age                    0.0
# hypertension           0.0
# heart_disease          0.0
# smoking_history        0.0
# bmi                    0.0
# HbA1c_level            0.0
# blood_glucose_level    0.0
# diabetes               0.0
# dtype: float64

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# # 3) Basic Visualization

# %% [markdown]
# # Uni Variant

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='diabetes',data=df)
plt.title('Result showing Diabetes')
plt.xlabel('diabetes')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='blood_glucose_level',data=df)
plt.title('Result Showing Diabetes')
plt.xlabel('blood_glucose_level')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='HbA1c_level',data=df)
plt.title('Result Showing Diabetes')
plt.xlabel('HbA1c_level')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.pointplot(x='heart_disease',data=df)
plt.title('Result Showing Diabetes')
plt.xlabel('heart_disease')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='hypertension',data=df)
plt.title('Result Showing Diabetes')
plt.xlabel('hypertension')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Bi variant

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='heart_disease',y='diabetes',hue='age',data=df)
plt.title('Results showing Diabetes')
plt.xlabel('heart disease')
plt.ylabel('diabetes')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='diabetes',y='hypertension',hue='age',data=df)
plt.title('Results showing diabetes')
plt.xlabel('diabetes')
plt.ylabel('hypertension')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='HbA1c_level',y='bmi',data=df)
plt.title('Results showing diabetes')
plt.xlabel('HbA1c_level')
plt.ylabel('bmi')
plt.show()

# %% [markdown]
# # Tri Variant

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='hypertension',data=df)
plt.title('Result Showing Diabetes')
plt.xlabel('hypertension')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='gender',y='diabetes',data=df)
plt.title('Result Showing Diabetes')
plt.xlabel('gender')
plt.ylabel('diabetes')
plt.show()

# %% [markdown]
# # 4)Correlation Heat map

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation matrix for diabetes dataset')
plt.show()

# %% [markdown]
# # 5) Feature Engineering

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %% [markdown]
# # 6) Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['gender']=le.fit_transform(df['gender'])

# %%
df['smoking_history']=le.fit_transform(df['smoking_history'])

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0             0              1                4  25.19
# 1       0  54.0             0              0                0  27.32
# 2       1  28.0             0              0                4  27.32
# 3       0  36.0             0              0                1  23.45
# 4       1  76.0             1              1                1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %% [markdown]
# # 7) Class Imbalance

# %%
print(df['diabetes'].value_counts())
print(df['diabetes'].value_counts(normalize=True))

import matplotlib.pyplot as plt
df['diabetes'].value_counts().plot(kind='bar')
plt.title('Results showing Diabetes')
plt.xlabel('diabetes')
plt.ylabel('count')
plt.show()
# Out:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64
# diabetes
# 0    0.915
# 1    0.085
# Name: proportion, dtype: float64

# %% [markdown]
# # 7) Class Imbalance

# %%
from sklearn.utils import resample

df_majority=df[df['diabetes'] == 0]
df_minority=df[df['diabetes'] == 1]

df_minority_oversampled = resample(df_minority,
                                   replace=True, 
                                   n_samples=len(df_majority),
                                   random_state=42)

df_oversampled=pd.concat([df_majority, df_minority_oversampled])

df_oversampled['diabetes'].value_counts(normalize=True)
# Out:
# diabetes
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
df_oversampled.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0             0              1                4  25.19
# 1       0  54.0             0              0                0  27.32
# 2       1  28.0             0              0                4  27.32
# 3       0  36.0             0              0                1  23.45
# 4       1  76.0             1              1                1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
print(df_oversampled['diabetes'].value_counts())
print(df_oversampled['diabetes'].value_counts(normalize=True))

import matplotlib.pyplot as plt
df_oversampled['diabetes'].value_counts().plot(kind='bar')
plt.title('Results showing Diabetes')
plt.xlabel('diabetes')
plt.ylabel('count')
plt.show()
# Out:
# diabetes
# 0    91500
# 1    91500
# Name: count, dtype: int64
# diabetes
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %% [markdown]
# # 8) Outliers Checking

# %%
numeric_cols=df.select_dtypes(include=np.number).columns
for col in numeric_cols:
    plt.figure(figsize=(4,6))
    sns.boxplot(y=df[col])
    plt.title(f'boxplot of {col}',fontsize=12)
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Outlier Reduction

# %%
Q1=df['bmi'].quantile(0.25)
Q3=df['bmi'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

# %%
df=df[(df['bmi']>=lower_bound)&(df['bmi']<=upper_bound)]

# %%
Q1=df['HbA1c_level'].quantile(0.25)
Q3=df['HbA1c_level'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

# %%
df=df[(df['HbA1c_level']>=lower_bound)&(df['HbA1c_level']<=upper_bound)]

# %%
Q1=df['blood_glucose_level'].quantile(0.25)
Q3=df['blood_glucose_level'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

# %%
df=df[(df['blood_glucose_level']>=lower_bound)&(df['blood_glucose_level']<=upper_bound)]

# %%
numeric_cols=df.select_dtypes(include=np.number).columns
for col in numeric_cols:
    plt.figure(figsize=(4,6))
    sns.boxplot(y=df[col])
    plt.title(f'boxplot of {col}',fontsize=12)
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %%
Q1=df['bmi'].quantile(0.25)
Q3=df['bmi'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

# %%
df=df[(df['bmi']>=lower_bound)&(df['bmi']<=upper_bound)]

# %%
numeric_cols=df.select_dtypes(include=np.number).columns
for col in numeric_cols:
    plt.figure(figsize=(4,6))
    sns.boxplot(y=df[col])
    plt.title(f'boxplot of {col}',fontsize=12)
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0             0              1                4  25.19
# 1       0  54.0             0              0                0  27.32
# 2       1  28.0             0              0                4  27.32
# 3       0  36.0             0              0                1  23.45
# 4       1  76.0             1              1                1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %% [markdown]
# # 9) Split into X and Y

# %%
X=df[['gender','age','hypertension','heart_disease','smoking_history','bmi','HbA1c_level','blood_glucose_level']]
Y=df[['diabetes']]

# %% [markdown]
# # 10) standardization

# %%
from scipy.stats import skew,kurtosis

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler() 
x=scaler.fit_transform(X)

# %%
x.shape
# Out:
# (84784, 8)

# %%
Y.shape
# Out:
# (84784, 1)

# %% [markdown]
# # Train Test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (67827, 8)

# %%
X_test.shape
# Out:
# (16957, 8)

# %%
Y_train.shape
# Out:
# (67827, 1)

# %%
Y_test.shape
# Out:
# (16957, 1)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score


lr_model=LogisticRegression()
lr_model.fit(X_train,Y_train)

y_lr_pred=lr_model.predict(X_test)

print('accuracy score of logistic regression: ',accuracy_score(y_lr_pred,Y_test))
print('confusion matrix of logistic regression:')
print(confusion_matrix(y_lr_pred,Y_test))
print('classification report of logistic regression: ',classification_report(y_lr_pred,Y_test))
# Out:
# c:\Users\hemae\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# accuracy score of logistic regression:  0.9637907648758625
# confusion matrix of logistic regression:
# [[16040   488]
#  [  126   303]]
# classification report of logistic regression:                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     16528
#            1       0.38      0.71      0.50       429
#
#     accuracy                           0.96     16957
#    macro avg       0.69      0.84      0.74     16957
# weighted avg       0.98      0.96      0.97     16957
# ...

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model=DecisionTreeClassifier()
dt_model.fit(X_train,Y_train)

y_dt_pred=dt_model.predict(X_test)

print('accuracy score of Decision Tree: ',accuracy_score(y_dt_pred,Y_test))
print('confusion matrix of Decision Tree: ')
print(confusion_matrix(y_lr_pred,Y_test))
print('classification report of Decision Tree: ',classification_report(y_lr_pred,Y_test))
# Out:
# accuracy score of Decision Tree:  0.9583652768768061
# confusion matrix of Decision Tree:
# [[16040   488]
#  [  126   303]]
# classification report of Decision Tree:                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     16528
#            1       0.38      0.71      0.50       429
#
#     accuracy                           0.96     16957
#    macro avg       0.69      0.84      0.74     16957
# weighted avg       0.98      0.96      0.97     16957

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model=RandomForestClassifier()
rf_model.fit(X_test,Y_test)

y_rf_pred=rf_model.predict(X_test)

print('accuracy score of Random Forest: ',accuracy_score(y_rf_pred,Y_test))
print('confusion matrix of Random Forest: ')
print(confusion_matrix(y_rf_pred,Y_test))
print('classification report of Random Forest: ',classification_report(y_rf_pred,Y_test))
# Out:
# c:\Users\hemae\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# accuracy score of Random Forest:  0.9995282184348646
# confusion matrix of Random Forest:
# [[16166     8]
#  [    0   783]]
# classification report of Random Forest:                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     16174
#            1       0.99      1.00      0.99       783
#
#     accuracy                           1.00     16957
#    macro avg       0.99      1.00      1.00     16957
# weighted avg       1.00      1.00      1.00     16957

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

svm_model=SVC()
svm_model.fit(X_test,Y_test)

y_svm_pred=svm_model.predict(X_test)

print('accuracy score of Support vector machine: ',accuracy_score(y_svm_pred,Y_test))
print('confusion matrix of support vector machine: ')
print(confusion_matrix(y_svm_pred,Y_test))
print('classification report of Support vector machine: ',classification_report(y_svm_pred,Y_test))
# Out:
# c:\Users\hemae\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# accuracy score of Support vector machine:  0.9582473314855222
# confusion matrix of support vector machine:
# [[16166   708]
#  [    0    83]]
# classification report of Support vector machine:                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     16874
#            1       0.10      1.00      0.19        83
#
#     accuracy                           0.96     16957
#    macro avg       0.55      0.98      0.58     16957
# weighted avg       1.00      0.96      0.97     16957

# %% [markdown]
# # XGBoost Algorithm

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from xgboost import XGBClassifier


xgboost_model=XGBClassifier()
xgboost_model.fit(X_test,Y_test)

y_xgboost_pred=xgboost_model.predict(X_test)

print('accuracy score of XGBoost: ',accuracy_score(y_xgboost_pred,Y_test))
print('confusion matrix of XGBoost: ')
print(confusion_matrix(y_xgboost_pred,Y_test))
print('classification report of XGBoost: ',classification_report(y_xgboost_pred,Y_test))
# Out:
# accuracy score of XGBoost:  0.9889131332193195
# confusion matrix of XGBoost:
# [[16165   187]
#  [    1   604]]
# classification report of XGBoost:                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     16352
#            1       0.76      1.00      0.87       605
#
#     accuracy                           0.99     16957
#    macro avg       0.88      0.99      0.93     16957
# weighted avg       0.99      0.99      0.99     16957

# %%
# Install LightGBM into the current Python environment and verify installation
import sys
import subprocess

try:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "lightgbm"])  # silent install may hide useful output
    import lightgbm as lgb
    print("LightGBM installed, version:", lgb.__version__)
except Exception as e:
    print("Failed to install or import LightGBM:", e)
# Out:
# LightGBM installed, version: 4.6.0

# %% [markdown]
# # Light GBM Algorithm

# %%
from lightgbm import LGBMClassifier

lightgbm_model=LGBMClassifier()
lightgbm_model.fit(X_test,Y_test)

y_lightgbm_pred=lightgbm_model.predict(X_test)

print('accuracy score of Light GBM: ',accuracy_score(y_lightgbm_pred,Y_test))
print('confusion matrix: ')
print(confusion_matrix(y_lightgbm_pred,Y_test))
print('classification report of Lightr GBM: ',classification_report(y_lightgbm_pred,Y_test))
# Out:
# c:\Users\hemae\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\hemae\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 791, number of negative: 16166
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000380 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 403
# ...

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint

# Use RandomizedSearchCV to limit runtime. It samples 20 candidates from the search space and runs 3-fold CV.
param_dist = {
    'n_estimators': randint(100, 301),
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': randint(2, 11),
}

model = RandomForestClassifier(random_state=42)

rand_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_dist,
    n_iter=20,
    cv=3,
    scoring='accuracy',
    n_jobs=-1,
    random_state=42,
    verbose=2
)

try:
    rand_search.fit(X_train, Y_train.values.ravel())
except KeyboardInterrupt:
    print('Search interrupted by user')

best_rf = rand_search.best_estimator_
y_r_pred = best_rf.predict(X_test)

print('Best Parameters: ', rand_search.best_params_)
print('Accuracy: ', accuracy_score(Y_test, y_r_pred))
print(classification_report(Y_test, y_r_pred))
print(confusion_matrix(Y_test, y_r_pred))
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best Parameters:  {'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 257}
# Accuracy:  0.976292976351949
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     16166
#            1       1.00      0.49      0.66       791
#
#     accuracy                           0.98     16957
#    macro avg       0.99      0.75      0.82     16957
# weighted avg       0.98      0.98      0.97     16957
#
# [[16166     0]
#  [  402   389]]

# %%
import joblib as jb
jb.dump(rf_model,'Diabetes.pkl')
# Out:
# ['Diabetes.pkl']

# %%
# Save the trained Random Forest model to a file
import joblib as jb
jb.dump(rf_model, 'Diabetes.pkl')
print('Diabetes.pkl saved')
# Out:
# Diabetes.pkl saved
